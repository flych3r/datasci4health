# %%
import pandas as pd
from google.colab import files

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
df = pd.read_csv("/content/drive/MyDrive//My_Inflamome_default_node.csv")

# %%
df
# Out:
#       AverageShortestPathLength  BetweennessCentrality  ClosenessCentrality  \
# 0                      4.404903               0.000508             0.227020
# 1                      3.408857               0.007408             0.293353
# 2                      4.930407               0.000000             0.202823
# 3                      3.930803               0.007895             0.254401
# 4                      4.930407               0.000000             0.202823
# ...                         ...                    ...                  ...
# 2525                   4.576908               0.000000             0.218488
# 2526                   4.576908               0.000000             0.218488
# 2527                   4.137999               0.000000             0.241663
# 2528                   4.206406               0.000000             0.237733
# 2529                   4.277185               0.000000             0.233799
#
# ...

# %%
dfMaioresDegree = df.sort_values(by=['Degree'], ascending=False)[['name', 'Degree', 'BetweennessCentrality']]
dfMaioresBetweeCent = df.sort_values(by=['BetweennessCentrality'], ascending=False)[['name', 'Degree', 'BetweennessCentrality']]

# %%
dfMaioresDegree.head(10)
# Out:
#         name  Degree  BetweennessCentrality
# 1245   TRAF6     362               0.159443
# 451      MYC     347               0.171132
# 440    IKBKE     346               0.167739
# 515     TP53     258               0.120523
# 639     EGFR     188               0.112698
# 866   MAP3K3     176               0.062795
# 2033   NFKB2     170               0.028986
# 1224    RELA     165               0.036781
# 1539   IKBKG     159               0.050406
# 1733   TRAF2     151               0.079403

# %%
dfMaioresBetweeCent.head(10)
# Out:
#         name  Degree  BetweennessCentrality
# 451      MYC     347               0.171132
# 440    IKBKE     346               0.167739
# 1245   TRAF6     362               0.159443
# 515     TP53     258               0.120523
# 639     EGFR     188               0.112698
# 1733   TRAF2     151               0.079403
# 866   MAP3K3     176               0.062795
# 1539   IKBKG     159               0.050406
# 82      GRB2      32               0.047384
# 383      UBC      41               0.045934

# %%
dfMaioresDegree.to_excel('dfMaioresDegree.xlsx')
dfMaioresBetweeCent.to_excel('dfMaioresBetweeCent.xlsx')
files.download('dfMaioresDegree.xlsx')
files.download('dfMaioresBetweeCent.xlsx')
